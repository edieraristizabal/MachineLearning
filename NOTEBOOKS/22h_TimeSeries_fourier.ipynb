# %% [markdown]
# **CURSO**: *Machine Learning* en Geociencias<br />
# **Profesor**: Edier Aristizábal (evaristizabalg@unal.edu.co) <br />
# **Credits**: The content of this notebook is taken from several sources: [The Fourier Transform and its Application in Machine Learning](https://medium.com/@evertongomede/the-fourier-transform-and-its-application-in-machine-learning-edecfac4133c), Everton Gomede en www.towardsdatascience.com. Every effort has been made to trace copyright holders of the materials used in this book. The author apologies for any unintentional omissions and would be pleased to add an acknowledgment in future editions.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # The Fourier Transform

# %% [markdown]
# The Fourier Transform is a mathematical operation that decomposes a signal into its constituent frequency components. It allows us to analyze the frequency content of a signal and represents it in the frequency domain. This transformation is particularly useful when dealing with complex signals, as it simplifies the analysis of their underlying patterns.

# %% [markdown]
# <center><img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/0*3SPZL7OBkn4RhLkG.gif" width="1000"></center>

# %% [markdown]
# <center><img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/0*BYkDIoldUKp4M3dB.gif" width="1000"></center>

# %%
# Generate a sample time series dataset
# You can replace this with your own time series data
# Ensure that the data is in a NumPy array or a list
time = np.arange(0, 10, 0.01)  # Time values from 0 to 10 with a step of 0.01
signal = 2 * np.sin(2 * np.pi * 1 * time) + 1 * np.sin(2 * np.pi * 2 * time)

# Plot the original time series
plt.figure(figsize=(10, 4))
plt.subplot(2, 1, 1)
plt.plot(time, signal)
plt.title('Original Time Series')
plt.xlabel('Time')
plt.ylabel('Amplitude')

# Perform the Fourier Transform
fourier_transform = np.fft.fft(signal)
frequencies = np.fft.fftfreq(len(signal), 0.01)  # Frequency values (assuming a sampling interval of 0.01)

# Plot the magnitude of the Fourier Transform
plt.subplot(2, 1, 2)
plt.plot(frequencies, np.abs(fourier_transform))
plt.title('Fourier Transform')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.xlim(0, 5)  # Limit the x-axis to show frequencies up to 5 Hz

plt.tight_layout()
plt.show()
