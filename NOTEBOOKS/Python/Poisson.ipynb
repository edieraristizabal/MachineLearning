# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
from numpy.random import randn
from numpy import random as rn
from scipy.stats import poisson
import scipy.stats as si
from matplotlib import pyplot as plt
import seaborn as sns
from IPython.display import Image
# %matplotlib inline

# %%
## Monte Carlo Model
Simulations = 1000
Lambda=12
f = np.arange(1,Simulations+1)
df = pd.DataFrame(data=f)
df['Poisson'] = np.random.poisson(Lambda, Simulations)
df.drop([0], axis=1, inplace=True)
df
# Out:
#      Poisson
# 0         15
# 1         12
# 2         14
# 3          9
# 4         17
# ..       ...
# 995       21
# 996       15
# 997       11
# 998       12
# 999       11
#
# [1000 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Poisson'].plot(kind='hist', bins=20, title='Poisson')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Poisson'].plot(kind='line', figsize=(8, 4), title='Poisson')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df['Poisson'].describe()
# Out:
# count    1000.000000
# mean       11.955000
# std         3.645856
# min         2.000000
# 25%         9.000000
# 50%        12.000000
# 75%        14.000000
# max        25.000000
# Name: Poisson, dtype: float64

# %%
countif = len(df[(df['Poisson'] == 15)])
count = len(df['Poisson'])
countif/count
# Out:
# 0.079

# %%
V = []
Simulations = 10
Trails = 1000
for j in range(0,Simulations):
    f = np.arange(1,Trails+1)
    df = pd.DataFrame(data=f)
    df['Poisson'] = np.random.poisson(Lambda,Trails)
    df.drop([0], axis=1, inplace=True)
    countif = len(df[(df['Poisson'] == 15)])
    count = len(df['Poisson'])
    qq = countif/count
    V.append(qq)

# %%
G = 1629562571
np.random.seed(G)
from datetime import datetime
start_time = datetime.now()
from datetime import datetime
# datetime object containing current date and time
now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
def NORMSINV(x):
    x = si.norm.ppf(x)
    return (x)
time_elapsed1 = datetime.now() - start_time
from scipy import stats
Workbook_Name = "Poisson Distribution.ipynb"
Number_of_Simulations = "{:,.0f}".format(Simulations)
Number_of_Iterations = "{:,.0f}".format(Trails)
Number_of_Inputs = "{:,.0f}".format(3)
Number_of_Outputs = 38
Sampling_Type = "Latin Hypercube"
Simulation_Start_Time = dt_string
Simulation_Duration = "{}".format(time_elapsed1)
Random_N_Generator = "Mersenne Twister"
Random_Seed = G
e = ["Workbook Name","Number of Simulations","Number of Iterations","Number of Inputs","Number of Outputs","Sampling Type",\
 "Simulation Start Time","Simulation Duration","Random # Generator","Random Seed"]
f = [Workbook_Name, Number_of_Simulations, Number_of_Iterations, Number_of_Inputs, Number_of_Outputs, Sampling_Type,\
 Simulation_Start_Time, Simulation_Duration, Random_N_Generator, Random_Seed]
Per5 = "{:,.4f}".format(np.percentile(V, 5))
P5 = "{:.0%}".format(0.05)
Per10 = "{:,.4f}".format(np.percentile(V, 10))
P10 = "{:.0%}".format(0.10)
Per15 = "{:,.4f}".format(np.percentile(V, 15))
P15 = "{:.0%}".format(0.15)
Per20 = "{:,.4f}".format(np.percentile(V, 20))
P20 = "{:.0%}".format(0.20)
Per25 = "{:,.4f}".format(np.percentile(V, 25))
P25 = "{:.0%}".format(0.25)
Per30 = "{:,.4f}".format(np.percentile(V, 30))
P30 = "{:.0%}".format(0.30)
Per35 = "{:,.4f}".format(np.percentile(V, 35))
P35 = "{:.0%}".format(0.35)
Per40 = "{:,.4f}".format(np.percentile(V, 40))
P40 = "{:.0%}".format(0.40)
Per45 = "{:,.4f}".format(np.percentile(V, 45))
P45 = "{:.0%}".format(0.45)
Per50 = "{:,.4f}".format(np.percentile(V, 50))
P50 = "{:.0%}".format(0.50)
Per55 = "{:,.4f}".format(np.percentile(V, 55))
P55 = "{:.0%}".format(0.55)
Per60 = "{:,.4f}".format(np.percentile(V, 60))
P60 = "{:.0%}".format(0.60)
Per65 = "{:,.4f}".format(np.percentile(V, 65))
P65 = "{:.0%}".format(0.65)
Per70 = "{:,.4f}".format(np.percentile(V, 70))
P70 = "{:.0%}".format(0.70)
Per75 = "{:,.4f}".format(np.percentile(V, 75))
P75 = "{:.0%}".format(0.75)
Per80 = "{:,.4f}".format(np.percentile(V, 80))
P80 = "{:.0%}".format(0.80)
Per85 = "{:,.4f}".format(np.percentile(V, 85))
P85 = "{:.0%}".format(0.85)
Per90 = "{:,.4f}".format(np.percentile(V, 90))
P90 = "{:.0%}".format(0.90)
Per95 = "{:,.4f}".format(np.percentile(V, 95))
P95 = "{:.0%}".format(0.95)
Minimum = "{:,.4f}".format(np.min(V))
Maximum = "{:,.4f}".format(np.max(V))
Mean = "{:,.4f}".format(np.mean(V))
Std_Dev = "{:,.4f}".format(np.std(V))
Variance = np.var(V)
Skewness = round(stats.skew(V),9)
Kurtosis = round((stats.kurtosis(V)+3),9)
Median = "{:,.4f}".format(np.median(V))
#Mode = "{:,.4f}".format(stats.mode(V)[0][0])
Left_X = Per5
Left_P = P5
Right_X = Per95
Right_P = P95
Diff_X = "{:,.4f}".format((np.percentile(V, 95) - np.percentile(V, 5)))
Diff_P = "{:.0%}".format(0.90)
Errors  = 0
Filter_Min = "Off"
Filter_Max = "Off"
Filtered = 0
g = {"Information": e, "Result": f}
st = pd.DataFrame(data=g)
a = ["Minimum","Maximum","Mean","Std Dev","Variance","Skewness","Kurtosis","Median","Left X"\
,"Left P","Right X","Right P","Diff X","Diff P","Errors","Filter_Min","Filter_Max","Filtered"]
b = [Minimum, Maximum, Mean, Std_Dev, Variance, Skewness, Kurtosis, Median, Left_X, Left_P, Right_X\
     ,Right_P, Diff_X, Diff_P, Errors, Filter_Min,Filter_Max,Filtered]
c = [P10,P15,P20,P25,P30,P35,P40,P45,P50,P55,P60,P65,P70,P75,P80,P85,P90,P95]
d = [Per10, Per15, Per20, Per25, Per30, Per35, Per40, Per45, Per50, Per55, Per60, Per65,\
 Per70, Per75, Per80, Per85, Per90, Per95]
d = {"Statistics": a, "Statistics Result": b, "Percentile": c, "Percentile Result": d}
st1 = pd.DataFrame(data=d)
from datetime import date
today = date.today()
now = datetime.now()
import calendar
curr_date = date.today()
print("\033[1m Simulation Summary Information")
print("\033[0m ================================================")
print("\033[1m Performed By:","\033[0mRoi Polanitzer")
print("\033[1m Date:","\033[0m",calendar.day_name[curr_date.weekday()],",",today.strftime("%B %d, %Y"),",",now.strftime("%H:%M:%S AM"))
st
# Out:
#  Simulation Summary Information
# ...
#  Performed By: Roi Polanitzer
#  Date:  Saturday , March 23, 2024 , 09:13:59 AM
#              Information                      Result
# 0          Workbook Name  Poisson Distribution.ipynb
# 1  Number of Simulations                          10
# 2   Number of Iterations                       1,000
# 3       Number of Inputs                           3
# 4      Number of Outputs                          38
# 5          Sampling Type             Latin Hypercube
# 6  Simulation Start Time         23/03/2024 09:13:59
# 7    Simulation Duration              0:00:00.000176
# 8     Random # Generator            Mersenne Twister
# 9            Random Seed                  1629562571

# %%
print("\033[1m Summary Statistics for Default Probability")
print("\033[0m ======================================================")
print("\033[1m Performed By:","\033[0mRoi Polanitzer")
print("\033[1m Date:","\033[0m",calendar.day_name[curr_date.weekday()],",",today.strftime("%B %d, %Y"),",",now.strftime("%H:%M:%S AM"))
st1
# Out:
#  Summary Statistics for Default Probability
# ...
#  Performed By: Roi Polanitzer
#  Date:  Saturday , March 23, 2024 , 09:13:59 AM
#     Statistics Statistics Result Percentile Percentile Result
# 0      Minimum            0.0650        10%            0.0659
# 1      Maximum            0.0890        15%            0.0674
# 2         Mean            0.0761        20%            0.0692
# 3      Std Dev            0.0076        25%            0.0708
# 4     Variance          0.000057        30%            0.0721
# 5     Skewness          0.123266        35%            0.0733
# 6     Kurtosis          1.942524        40%            0.0742
# 7       Median            0.0760        45%            0.0751
# 8       Left X            0.0655        50%            0.0760
# 9       Left P                5%        55%            0.0769
# 10     Right X            0.0872        60%            0.0774
# 11     Right P               95%        65%            0.0779
# ...

# %%
plt.figure(figsize = (4,4))
sns.set(font_scale = 1.2)
ax = sns.histplot(data=V,bins=10,color="red")
ax.set_xlabel("Default Probability",fontsize=14)
ax.set_ylabel("Frequency",fontsize=14)
ax.set_xlim(0.0620,0.095)
print("\033[1m Probability Density Function for Default Probability (Sim#1)")
print("\033[0m ============================================================")
print("\033[1m Performed By:","\033[0mRoi Polanitzer")
print("\033[1m Date:","\033[0m",calendar.day_name[curr_date.weekday()],",",today.strftime("%B %d, %Y"),",",now.strftime("%H:%M:%S AM"))
# Out:
#  Probability Density Function for Default Probability (Sim#1)
# ...
#  Performed By: Roi Polanitzer
#  Date:  Saturday , March 23, 2024 , 09:13:59 AM

# %%
plt.figure(figsize = (4,4))
kwargs = {"cumulative": True}
sns.axes_style("whitegrid")
sns.set(font_scale = 1.2)
ax = sns.distplot(V, hist_kws=None, kde_kws=kwargs,color="red")
ax.set_xlabel("Default Probability",fontsize=14)
ax.set_ylabel("Frequency",fontsize=14)
ax.set_xlim(0.0620,0.095)
print("\033[1m Cumulative Distribution Function for Default Probability (Sim#1)")
print("\033[0m ================================================================")
print("\033[1m Performed By:","\033[0mRoi Polanitzer")
print("\033[1m Date:","\033[0m",calendar.day_name[curr_date.weekday()],",",today.strftime("%B %d, %Y"),",",now.strftime("%H:%M:%S AM"))
# Out:
# <ipython-input-18-6c47668c3c89>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(V, hist_kws=None, kde_kws=kwargs,color="red")
#  Cumulative Distribution Function for Default Probability (Sim#1)
# ...
#  Performed By: Roi Polanitzer
#  Date:  Saturday , March 23, 2024 , 09:13:59 AM

# %% [markdown]
# In order to predict the default probability, I used the Monte Carlo simulations and the Poisson distribution. The Monte Carlo simulations is widely used in situations where there is no analytical solution and other approaches (such as binomial tree).
#
# The Monte Carlo simulations uses a simulation of risk factors according to an assumed probability distribution and then calculates the default probability for each simulation separately. The average value of the default probability is referred as the estimated value of the default probability.
#
# Standard error of sample mean typically serves as an indication of the level of precision of the model. Since this standard error declines very slow with the number of simulations typically one need to use dozens of thousands (or even more) of sample simulations in order to arrive at an acceptable level of accuracy.
#
# In forecasts, we can determine the probability of occurrence called confidence interval. That is, given two values, what are the chances that the outcome will fall between these two values?
#
# I have used 10 Monte Carlo simulations each of which consists of 1,000 iterations (1000 times of 1 trial) — so that in total I have used 10,000 random numbers (10 simulations multiplied by 1,000 iterations) in this calculation.
#
# There is a 90% probability that the final outcome (in this case, the default probability) will be between 6.25% and 8.21%. On the other hand, there is a 5% probability that sales volume will be below 6.25% and another 5% probability that sales volume will be above 8.21%.
#
# That is, the two-tailed confidence interval is a symmetrical interval centered on the mean value, the median value (i.e., the 50th percentile value) or the mode value. Thus, both tails will have the same probability.
#
# The average value of the estimated probability that exactly 15 Israeli companies listed on the Nasdaq will default in the coming year is 7.30%, the median value is 7.35% and the mode value is 7.30%.
