# %% [markdown]
# Curso: Datos Geoespaciales
# Profesor: Edier Aristizabal (evaristizabalg@unal.edu.co)
# Curso website: https://unvirtual.medellin.unal.edu.co/course/view.php?id=579

# %% [markdown]
# # 02: Datos Geoespaciales

# %% [markdown]
# ## Cómo importar los datos

# %% [markdown]
# ### Introducción

# %% [markdown]
# A continuación se presentan diferentes formas y funciones para importar y exportar datos. Labor inicial que se requiere para iniciar la construcción del modelo.
#
# Inicialmente se deben importar todas las librerias que se reqeuiren en los diferentes procedimientos. Existen diferentes librerias para importar archivos con formatos diferentes, aca se presentan algunas de las mas utilizadas y conocidas.
#
# Para importar mapas en formato tiff uno de los paquetes mas utilizados es gdal, tambien existen otros como rasterio, entre otros.
#
# Para exportar archivos en formato xlsx se reqeuire el paquete openpyxl.
#
# Para trabajar con archivos tipo bin, se requiere  el paquete pickle.
#
# Y para trabajar con archivos tipo .nc se requiere el paquete netCDF4.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from osgeo import gdal
import pickle
import openpyxl
import netCDF4 as nc

# %%
xlsx= pd.read_excel('G:\My Drive\ANALISIS ESPACIAL APLICADO\datos\Cuencas_torrencialidad.xlsx', sheet_name='Hoja2')
print(xlsx.shape)
xlsx.tail(5)
# Out:
# (73, 32)
#                                             Name  Cuenca  Main Stream Order  \
# 68               RIO VALLECITOS (Líbano, Tolima)      69                  2
# 69   RIO ESPIRITU SANTO (Agustín Codazzi, Cesar)      70                  5
# 70  QUEBRADA AGUA FRIA (Contratación, Santander)      71                  2
# 71         QUEBRADA SANTO CRISTO (Soatá, Boyacá)      72                  3
# 72            QUEBRADA LIBARE (Salamina, Caldas)      73                  2
#
#     Number of streams  Stream Lenght  Main Stream Leght   Stream Lenght Ratio  \
# 68                  6         26.589              19.400             1.036847
# 69                132        371.352              66.906             1.933738
# 70                  9         23.183              10.146             1.720253
# 71                  9         28.589              13.976             2.158894
# 72                  4          5.103               3.284             1.703763
#
#     Bifurcation Ratio   Ro Coefficient  Lenght of Basin         ...          \
# 68            5.000000        4.822313           21.810         ...
# 69            3.497222        2.576631           70.369         ...
# 70            8.000000        4.650477           12.510         ...
# 71            2.500000        1.184412           15.841         ...
# 72            3.000000        1.760809            5.650         ...
#
#     Drainage Intensity  Infiltrarion Number  Leght of overland flow  Relief  \
# 68            0.225657             0.184657                0.552729   1.970
# 69            0.355458             0.155114                0.756900   3.442
# 70            0.388216             0.224086                0.658112   1.576
# 71            0.314806             0.123162                0.799381   2.033
# 72            0.783853             0.261915                0.864981   0.563
#
#     Mean Basin Slope  Relief Ratio  Rudgeness Number  Melton Index  Ln Melton  \
# 68            15.250      0.074091          1.782068      0.033134  -3.407183
# 69            24.740      0.009269          2.273747      0.004956  -5.307082
# 70            25.196      0.067981          1.197365      0.024035  -3.728250
# 71            25.220      0.071111          1.271609      0.044975  -3.101655
# 72            17.086      0.110327          0.325441      0.063697  -2.753610
#
#     Flash flood record
# 68                   0
# 69                   0
# 70                   0
# 71                   0
# 72                   0
#
# [5 rows x 32 columns]

# %%
data=(xlsx.iloc[:,4])
print(data.shape)
data.head(5)
# Out:
# (73,)
# 0     4.9820
# 1     6.5693
# 2    31.8530
# 3    26.4590
# 4    10.4070
# Name: Stream Lenght, dtype: float64

# %%
writer = xlsx.to_excel('G:\My Drive\ANALISIS ESPACIAL APLICADO\datos\DF_prueba.xlsx')

# %%
driver = gdal.GetDriverByName('GTiff')
file = gdal.Open('G:\My Drive\ANALISIS ESPACIAL APLICADO\datos\dtm_Arenosa')
raster = file.GetRasterBand(1)
dem = raster.ReadAsArray()
plt.imshow(dem)
plt.colorbar();

# %%
geologia=np.loadtxt('G:/My Drive/ANALISIS ESPACIAL APLICADO/datos/raster/gamma.asc', skiprows=6)
geologia=np.where(geologia==-9999.,np.nan,geologia)
plt.imshow(geologia)
plt.colorbar();

# %%
FS_hazard  = np.genfromtxt('G:/My Drive/PAPERS/ELABORACION/SHIA_George/resultados/FS_AMEACA.txt')
plt.imshow(FS_hazard)
plt.colorbar();

# %%
f=open('G:\My Drive\ANALISIS ESPACIAL APLICADO\datos\prueba.txt','w')
f.write('prueba')
f.close()

# %%
file=open('G:\My Drive\ANALISIS ESPACIAL APLICADO\datos\prueba_binario.bin','wb')
pickle.dump(data, file)
file.close()

# %%
file= open('G:\My Drive\ANALISIS ESPACIAL APLICADO\datos\prueba_binario.bin', 'rb')
vector=pickle.load(file)
file.close()
vector.head(5)
# Out:
# 0     4.9820
# 1     6.5693
# 2    31.8530
# 3    26.4590
# 4    10.4070
# Name: Stream Lenght, dtype: float64

# %%
CHIRPS = nc.Dataset('G:\My Drive\ANALISIS ESPACIAL APLICADO\datos\chirps-v2.0.monthly.nc')
VARS   = [x for x in CHIRPS.variables]
print(VARS)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-2992e9962472> in <module>
# ----> 1 CHIRPS = nc.Dataset('G:\My Drive\ANALISIS ESPACIAL APLICADO\datos\chirps-v2.0.monthly.nc')
#       2 VARS   = [x for x in CHIRPS.variables]
#       3 print(VARS)
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -101] NetCDF: HDF error: b'G:\\My Drive\\ANALISIS ESPACIAL APLICADO\\datos\\chirps-v2.0.monthly.nc'

# %%
file_out = driver.Create( 'G:/My Drive/ANALISIS ESPACIAL APLICADO/datos/raster/dem_out.tif', file.RasterXSize , file.RasterYSize , 1)
file_out.GetRasterBand(1).WriteArray(dem)

# spatial ref system
proj = file.GetProjection()
georef = file.GetGeoTransform()
file_out.SetProjection(proj)
file_out.SetGeoTransform(georef)
file_out.GetRasterBand(1).SetNoDataValue(-9999)
file_out.FlushCache()

# %%
composite = gdal.Open('G:/My Drive/SENSORES REMOTOS/TALLERES/Taller 2_LANDSAT_ArcGIS/Imagen/barranquilla/Composite_LE70090532003066EDC00.tif')
raster = composite.GetRasterBand(1)
B1= raster.ReadAsArray()
plt.imshow(B1);

# %%
raster = composite.GetRasterBand(2)
B2= raster.ReadAsArray()
plt.imshow(B2);

# %%
raster = composite.GetRasterBand(3)
B3= raster.ReadAsArray()
plt.imshow(B3);

# %%
file = gdal.Open('G:/My Drive/ANALISIS ESPACIAL APLICADO/datos/VdeA/2014.B3.tif')
raster = file.GetRasterBand(1)
B1= raster.ReadAsArray()
plt.imshow(B1);

# %%
plt.hist(B1, bins=100, lw=0.0, stacked=False, alpha=0.3,histtype='stepfilled');

# %% [markdown]
# ![](images/numpy-intro/array_1.png)
